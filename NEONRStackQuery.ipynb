# %%
run basemodel_packages.ipynb
# Out:
# The downloaded binary packages are in
# 	/var/folders/n1/llghv0zn50593q04g48gt1400000gn/T//RtmpPssnIg/downloaded_packages

# %%
products = ['DP1.00047.001', 'DP1.00096.001', 'DP1.10008.001', 'DP1.00097.001', 'DP1.10078.001', 'DP1.10100.001', 
'DP1.00095.001', 'DP1.00094.001', 'DP1.00040.001', 'DP1.00041.001', 'DP1.10080.001', 'DP1.10086.001', 'DP1.10066.001', 
'DP1.10107.001', 'DP1.00066.001', 'DP1.10067.001', 'DP1.10104.001', 'DP1.10109.001', 'DP1.00005.001', 'DP1.00098.001', 
'DP1.10099.001', 'DP1.00023.001', 'DP1.10108.001', 'DP1.00004.001', 'DP1.00004.001', 'DP4.00200.001', 'DP1.00006.001', 'DP1.10102.001']

# %%
products.sort()

# %%
products
# Out:
# ['DP1.00004.001',
#  'DP1.00004.001',
#  'DP1.00005.001',
#  'DP1.00006.001',
#  'DP1.00023.001',
#  'DP1.00040.001',
#  'DP1.00041.001',
#  'DP1.00047.001',
#  'DP1.00066.001',
#  'DP1.00094.001',
#  'DP1.00095.001',
#  'DP1.00096.001',
#  'DP1.00097.001',
#  'DP1.00098.001',
#  'DP1.10008.001',
#  'DP1.10066.001',
#  'DP1.10067.001',
#  'DP1.10078.001',
#  'DP1.10080.001',
#  'DP1.10086.001',
#  'DP1.10099.001',
#  'DP1.10100.001',
#  'DP1.10102.001',
#  'DP1.10104.001',
#  'DP1.10107.001',
#  'DP1.10108.001',
#  'DP1.10109.001',
#  'DP4.00200.001']

# %%
# Provide list of sites within domain - AK
# Tundra: "BARR", "OKSR", "TOOK", "TOOL"
# Taiga: "BONA", "CARI", "DEJU", "HEAL"
site_list = ["BARR", "OKSR", "TOOK", "TOOL", "BONA", "CARI", "DEJU", "HEAL"]

# %%
neonUtilities.getAPI('http://data.neonscience.org/api/v0/', token = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJFUzI1NiJ9.eyJhdWQiOiJodHRwczovL2RhdGEubmVvbnNjaWVuY2Uub3JnL2FwaS92MC8iLCJzdWIiOiJiZ2F5MkBnbXUuZWR1Iiwic2NvcGUiOiJyYXRlOnB1YmxpYyIsImlzcyI6Imh0dHBzOi8vZGF0YS5uZW9uc2NpZW5jZS5vcmcvIiwiZXhwIjoxNzQ4ODg3MDk3LCJpYXQiOjE1OTEyMDcwOTcsImVtYWlsIjoiYmdheTJAZ211LmVkdSJ9.EjU1idgR8Be7Wt7uRGI1k850-n3A3y3YEHUrqb87sPnfowjlhPvC4DCDWl1k3N2IZ-IOt1NirSWWXxeTSGbXtQ')
# Out:
# R object with classes: ('response',) mapped to:
# [StrSexpVe..., IntSexpVe..., ListSexpV..., ListSexpV..., ..., FloatSexp..., FloatSexp..., ListSexpV..., SexpExtPtr]
#   url: <class 'rpy2.robjects.vectors.StrVector'>
#   R object with classes: ('character',) mapped to:
# ['https://data.neonscience.org/api/v0/']
#   status_code: <class 'rpy2.robjects.vectors.IntVector'>
#   R object with classes: ('RTYPES.INTSXP',) mapped to:
# [404]
# R object with classes: ('response',) mapped to:
# [StrSexpVe..., IntSexpVe..., ListSexpV..., ListSexpV..., ..., FloatSexp..., FloatSexp..., ListSexpV..., SexpExtPtr]
# R object with classes: ('response',) mapped to:
# [StrSexpVe..., IntSexpVe..., ListSexpV..., ListSexpV..., ..., FloatSexp..., FloatSexp..., ListSexpV..., SexpExtPtr]
# ...
#   content: <class 'rpy2.robjects.vectors.POSIXct'>
#   R object with classes: ('POSIXct', 'POSIXt') mapped to:
# [2020-06-1...]
#   date: <class 'rpy2.robjects.vectors.FloatVector'>
# ...

# %%
data = {}
for i in range(len(site_list)):
    rr = requests.get('https://data.neonscience.org/api/v0/sites/{}'.format(site_list[i]))    
    data[i] = json.loads(rr.text)
    i =+ 1

# %%
data
# Out:
# {0: {'data': {'siteCode': 'BARR',
#    'siteName': 'Utqiaġvik, RELOCATABLE',
#    'siteDescription': 'Utqiaġvik',
#    'siteType': 'RELOCATABLE',
#    'siteLatitude': 71.28241,
#    'siteLongitude': -156.61936,
#    'stateCode': 'AK',
#    'stateName': 'Alaska',
#    'domainCode': 'D18',
#    'domainName': 'Tundra',
#    'dataProducts': [{'dataProductCode': 'DP1.00001.001',
#      'dataProductTitle': '2D wind speed and direction',
#      'availableMonths': ['2017-07',
#       '2017-08',
#       '2017-10',
#       '2017-11',
#       '2017-12',
#       '2018-01',
#       '2018-02',
#       '2018-03',
#       '2018-04',
#       '2018-05',
#       '2018-06',
#       '2018-07',
#       '2018-08',
#       '2018-09',
#       '2018-10',
#       '2018-11',
#       '2018-12',
#       '2019-01',
#       '2019-02',
#       '2019-03',
#       '2019-04',
#       '2019-05',
#       '2019-06',
#       '2019-07',
#       '2019-08',
#       '2019-09',
#       '2019-10',
#       '2019-11',
# ...

# %%
def func1(data):
    for key,value in data.items():
        print (str(key)+'->'+str(value))
        if type(value) == type(dict()):
            func1(value)
        elif type(value) == type(list()):
            for val in value:
                if type(val) == type(str()):
                    pass
                elif type(val) == type(list()):
                    pass
                else:
                    func1(val)
soildata_flatten = func1(data)
# Out:
# 0->{'data': {'siteCode': 'BARR', 'siteName': 'Utqiaġvik, RELOCATABLE', 'siteDescription': 'Utqiaġvik', 'siteType': 'RELOCATABLE', 'siteLatitude': 71.28241, 'siteLongitude': -156.61936, 'stateCode': 'AK', 'stateName': 'Alaska', 'domainCode': 'D18', 'domainName': 'Tundra', 'dataProducts': [{'dataProductCode': 'DP1.00001.001', 'dataProductTitle': '2D wind speed and direction', 'availableMonths': ['2017-07', '2017-08', '2017-10', '2017-11', '2017-12', '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12', '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2020-01', '2020-02', '2020-03', '2020-04', '2020-05'], 'availableDataUrls': ['https://data.neonscience.org/api/v0/data/DP1.00001.001/BARR/2017-07', 'https://data.neonscience.org/api/v0/data/DP1.00001.001/BARR/2017-08', 'https://data.neonscience.org/api/v0/data/DP1.00001.001/BARR/2
# ...

# %%
neonUtilities.getDatatable(
    sample_site_dpid = data.dataProducts
    sample_site_name = data.siteName,
    sample_site_type = data.siteType,
    sample_site_code = data.siteCode,
    sample_site_location = [data.siteLatitude, data.siteLongitude],
    sample_date_min = "2012-01-01",
    sample_date_max = date.today().strftime('%Y-%m-%d'),
    sample_date_format = "%Y-%m-%d",
    data_package_type = "basic",
    url_prefix_data = "https://data.neonscience.org/api/v0/data/",
    url_prefix_products = "https://data.neonscience.org/api/v0/products/",
    token = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJFUzI1NiJ9.eyJhdWQiOiJodHRwczovL2RhdGEubmVvbnNjaWVuY2Uub3JnL2FwaS92MC8iLCJzdWIiOiJiZ2F5MkBnbXUuZWR1Iiwic2NvcGUiOiJyYXRlOnB1YmxpYyIsImlzcyI6Imh0dHBzOi8vZGF0YS5uZW9uc2NpZW5jZS5vcmcvIiwiZXhwIjoxNzQ4ODg3MDk3LCJpYXQiOjE1OTEyMDcwOTcsImVtYWlsIjoiYmdheTJAZ211LmVkdSJ9.EjU1idgR8Be7Wt7uRGI1k850-n3A3y3YEHUrqb87sPnfowjlhPvC4DCDWl1k3N2IZ-IOt1NirSWWXxeTSGbXtQ'
)

# %%
neonUtilities.readTableNEON(soil_data)
soil_data
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-173-a46f6b007928> in <module>
# ----> 1 neonUtilities.readTableNEON(soil_data)
#       2 soil_data
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/robjects/functions.py in __call__(self, *args, **kwargs)
#     196                 kwargs[r_k] = v
#     197         return (super(SignatureTranslatedFunction, self)
# --> 198                 .__call__(*args, **kwargs))
#     199
#     200
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/robjects/functions.py in __call__(self, *args, **kwargs)
#     115
#     116     def __call__(self, *args, **kwargs):
# --> 117         new_args = [conversion.py2rpy(a) for a in args]
#     118         new_kwargs = {}
#     119         for k, v in kwargs.items():
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/robjects/functions.py in <listcomp>(.0)
#     115
# ...

# %%
soil_data

# %%
neonUtilities.readTableNEON(data)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-186-3a2ff78622aa> in <module>
# ----> 1 neonUtilities.readTableNEON(data)
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/robjects/functions.py in __call__(self, *args, **kwargs)
#     196                 kwargs[r_k] = v
#     197         return (super(SignatureTranslatedFunction, self)
# --> 198                 .__call__(*args, **kwargs))
#     199
#     200
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/robjects/functions.py in __call__(self, *args, **kwargs)
#     115
#     116     def __call__(self, *args, **kwargs):
# --> 117         new_args = [conversion.py2rpy(a) for a in args]
#     118         new_kwargs = {}
#     119         for k, v in kwargs.items():
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/robjects/functions.py in <listcomp>(.0)
#     115
#     116     def __call__(self, *args, **kwargs):
# ...

# %%
#dpID == products
#while TRUE
#while dpID == products:
#    neonUtilities.zipsByProduct(dpID='DP1.00095.001', site=base.c('BARR','BONA', 'CARI', 'DEJU', 'HEAL', 'OKSR', 
#        'TOOK', 'TOOL'), savepath='~/Downloads', package='basic', check_size='FALSE');
#    else

# %%
neonUtilities.stackByTable(filepath='~/Downloads/ABoVE_soil/NEON/')
# Out:
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# <ipython-input-124-5722a796feb2> in <module>
# ----> 1 neonUtilities.stackByTable(filepath='~/Downloads/ABoVE_soil/NEON/')
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/robjects/functions.py in __call__(self, *args, **kwargs)
#     196                 kwargs[r_k] = v
#     197         return (super(SignatureTranslatedFunction, self)
# --> 198                 .__call__(*args, **kwargs))
#     199
#     200
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/robjects/functions.py in __call__(self, *args, **kwargs)
#     123             else:
#     124                 new_kwargs[k] = conversion.py2rpy(v)
# --> 125         res = super(Function, self).__call__(*new_args, **new_kwargs)
#     126         res = conversion.rpy2py(res)
#     127         return res
#
# ...

# %%
neonUtilities.zipsByProduct(dpID='DP1.10003.001', 
                            site=base.c('HARV','BART'), 
                            savepath='~/Downloads',
                            package='basic', 
                            check_size='FALSE');

# %%
import os
os.listdir('Downloads/ABoVE_soil/NEON/')

# %%
cwd = os.getcwd()  # Get the current working directory (cwd)
files = os.listdir(cwd)  # Get all the files in that directory
print("Files in %r: %s" % (cwd, files))

# %%
os.getcwd()

# %%
productfilelist = os.listdir('Downloads/ABoVE_soil/NEON/filesToStack00004/stackedFiles/')

# %%
contentfolders = os.walk('Downloads/ABoVE_soil/NEON/filesToStack00004/stackedFiles')

# %%
contentfolders
